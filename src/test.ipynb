# %%
import pandas as pd
import requests
from io import StringIO
import pymongo
from pymongo import MongoClient

# %%
file_requests = pd.read_csv(r'C:\Users\jjs61\OneDrive\Desktop\Student_performance\student-mat.csv')
file_requests.head()

# %%
# File path to the CSV file
file_path = r"C:\Users\jjs61\OneDrive\Desktop\Student_performance\src\data\student-mat.csv"

# Read in the Data
df = pd.read_csv(file_path, delimiter=';')  # Adjusted Delimiter


display(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.columns = df.columns.str.replace(' ', '_').str.strip().str.lower()

# %%
df.keys()
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'pstatus', 'medu', 'fedu',
#        'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'dalc',
#        'walc', 'health', 'absences', 'g1', 'g2', 'g3'],
#       dtype='object')

# %%
# File path to the CSV file
file_path = r"C:\Users\jjs61\OneDrive\Desktop\Student_performance\src\data\student-mat.csv"

# Read in the Data
df = pd.read_csv(file_path, delimiter=';')  # Adjusted Delimiter


display(df)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# Create file path variables

file_path1 = r'C:\Users\jjs61\OneDrive\Desktop\Student_performance\src\data\student-mat.csv'
file_path2 = r'C:\Users\jjs61\OneDrive\Desktop\Student_performance\src\data\student-por.csv'

# %%
# Read in the file paths and add the students class of record

df1 = pd.read_csv(file_path1, delimiter=';')
df1['class_type'] = 'math'
df2 = pd.read_csv(file_path2, delimiter=';')
df2['class_type'] = 'portuguese'
combined_requests = [df1,df2]
df = pd.concat(combined_requests)
df.index = df.index.astype(str)
df.index.rename('student_id', inplace=True)

# %%
# Format the column titles 
df.columns = df.columns.str.replace(' ', '_').str.strip().str.lower()
# Concat both dataframes and create and index name 'student_id'

df.head()
# Out:
#            school sex  age address famsize pstatus  medu  fedu     mjob  \
# student_id
# 0              GP   F   18       U     GT3       A     4     4  at_home
# 1              GP   F   17       U     GT3       T     1     1  at_home
# 2              GP   F   15       U     LE3       T     1     1  at_home
# 3              GP   F   15       U     GT3       T     4     2   health
# 4              GP   F   16       U     GT3       T     3     3    other
#
#                 fjob  ... freetime goout  dalc  walc  health absences  g1  g2  \
# student_id            ...
# 0            teacher  ...        3     4     1     1       3        6   5   6
# 1              other  ...        3     3     1     1       3        4   5   5
# 2              other  ...        3     2     2     3       3       10   7   8
# 3           services  ...        2     2     1     1       5        2  15  14
# 4              other  ...        3     2     1     2       5        4   6  10
#
# ...

# %%
# Obtain MongoDB connection mongodb+srv://jjs187:sydney187@cluster0.hd9gpz1.mongodb.net/?retryWrites=true&w=majority

con_str = 'mongodb+srv://jjs187:sydney187@cluster0.hd9gpz1.mongodb.net/?retryWrites=true&w=majority'

# %%
client = pymongo.MongoClient(con_str)

# %% [markdown]
# # Create a databse
# # Create a collection from from the database

# %%
# create a database
db = client.db
print(type(db))
db
# Out:
# <class 'pymongo.database.Database'>
# Database(MongoClient(host=['ac-dkixq8l-shard-00-00.hd9gpz1.mongodb.net:27017', 'ac-dkixq8l-shard-00-01.hd9gpz1.mongodb.net:27017', 'ac-dkixq8l-shard-00-02.hd9gpz1.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-16a0ah-shard-0', tls=True), 'db')

# %%
# Create a collection from the database
student_info = db.student_info
print(type(student_info))
# Out:
# <class 'pymongo.collection.Collection'>

# %%
# try to insert many
student_info.insert_many([df.to_dict()])

# %% [markdown]
# for i in df.index[:3]:
#     df.insert_one(df.loc[i].to_dict())
